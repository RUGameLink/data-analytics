# %% [markdown]
# <a href="https://colab.research.google.com/github/RUGameLink/data-analytics/blob/main/lb3v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D

# %%
PLOT_LABEL_FONT_SIZE = 25

def getColors(n):
  COLORS = [] 
  cm = plt.cm.get_cmap('hsv', n)
  for i in np.arange(n):
    COLORS.append(cm(i))
  return COLORS

# %%
def dict_sort(my_dict):
  keys = []
  values = []
  my_dict = sorted(my_dict.items(), key=lambda x:x[1], reverse=True)
  for k, v in my_dict:
    keys.append(k)
    values.append(v)
  return (keys,values)

# %%
df = pd.read_csv('./drive/MyDrive/vgsales.csv', escapechar='`', low_memory=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = df.replace({None: 'unknown'})
df = df.replace({np.NaN: 'unknown'})
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
breed_count = pd.value_counts(df['Genre'].values, sort=True)
breed_count_keys, breed_count_values = dict_sort(dict(breed_count))  
TOP_breed = len(breed_count_keys)
plt.figure(figsize=(20,10))
plt.title('Жанры', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), breed_count_values, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), breed_count_keys, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр в жанре', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
breed_count = pd.value_counts(df['Publisher'].values, sort=True)
breed_count_keys, breed_count_values = dict_sort(dict(breed_count))  
print(range(len(breed_count_keys)))
del breed_count_values[50:579]
del breed_count_keys[50:579]
TOP_breed = len(breed_count_keys)
plt.figure(figsize=(20,10))
plt.title('Издатель', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), breed_count_values, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), breed_count_keys, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр в издании', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()
# Out:
# range(0, 579)

# %%
breed_count = pd.value_counts(df['Publisher'].values, sort=True)
breed_count_keys, breed_count_values = dict_sort(dict(breed_count))  
print(range(len(breed_count_keys)))
del breed_count_values[0:50]
del breed_count_keys[0:50]
del breed_count_values[50:579]
del breed_count_keys[50:579]
TOP_breed = len(breed_count_keys)
plt.figure(figsize=(20,10))
plt.title('Издатель', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), breed_count_values, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), breed_count_keys, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр в издании', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()
# Out:
# range(0, 579)

# %%
breed_count = pd.value_counts(df['Platform'].values, sort=True)
breed_count_keys, breed_count_values = dict_sort(dict(breed_count))  
TOP_breed = len(breed_count_keys)
plt.figure(figsize=(20,10))
plt.title('Платформы', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), breed_count_values, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), breed_count_keys, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр на платформе', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
breed_count = pd.value_counts(df['Year'].values, sort=True)
breed_count_keys, breed_count_values = dict_sort(dict(breed_count))  
del breed_count_values[20]
del breed_count_keys[20]
TOP_breed = len(breed_count_keys)
plt.figure(figsize=(20,10))
plt.title('Год издания', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), breed_count_values, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), breed_count_keys, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %% [markdown]
# ================================================================================

# %%
pl_count = pd.value_counts(df['Platform'].values, sort=True)
#print(list(dict(pl_count).keys())[1])
platorm = np.empty(df['Platform'].values.size, dtype = object)
for i in range(pl_count.values.size):
  if(list(dict(pl_count).values())[i] > 1000):
    platorm[i] =(list(dict(pl_count).keys())[i])
  else:
    break
print(platorm)
for i in range(platorm.size):
  if(platorm[i] != None):
    print(platorm[i])
    response = df[df['Platform'].isin(platorm)]

platorm1 = response[response['Platform'] == platorm[0]]
platorm2 = response[response['Platform'] == platorm[1]]
platorm3 = response[response['Platform'] == platorm[2]]
platorm4 = response[response['Platform'] == platorm[3]]
platorm5 = response[response['Platform'] == platorm[4]]
platorm6 = response[response['Platform'] == platorm[5]]
platorm7 = response[response['Platform'] == platorm[6]]
# Out:
# ['DS' 'PS2' 'PS3' ... None None None]
# DS
# PS2
# PS3
# Wii
# X360
# PSP
# PS

# %%
year_count1 = pd.value_counts(platorm1['Year'].values, sort=True)
year_count_keys1, year_count_values1 = dict_sort(dict(year_count1)) 
del year_count_values1[7]
del year_count_keys1[7]

for i in range(year_count1.values.size-1):
  j=i+1
  for j in range(year_count1.values.size-1):
    if(year_count_keys1[j]>year_count_keys1[i]):
      h = year_count_values1[j]
      year_count_values1[j] = year_count_values1[i]
      year_count_values1[i] = h

      n = year_count_keys1[j]
      year_count_keys1[j] = year_count_keys1[i]
      year_count_keys1[i] = n


TOP_breed = len(year_count_keys1)
plt.figure(figsize=(20,10))
plt.title('Год издания DS', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), year_count_values1, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), year_count_keys1, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
year_count2 = pd.value_counts(platorm2['Year'].values, sort=True)
year_count_keys2, year_count_values2 = dict_sort(dict(year_count2)) 
del year_count_values2[11]
del year_count_keys2[11]

for i in range(year_count2.values.size-1):
  j=i+1
  for j in range(year_count2.values.size-1):
    if(year_count_keys2[j]>year_count_keys2[i]):
      h = year_count_values2[j]
      year_count_values2[j] = year_count_values2[i]
      year_count_values2[i] = h

      n = year_count_keys2[j]
      year_count_keys2[j] = year_count_keys2[i]
      year_count_keys2[i] = n

TOP_breed = len(year_count_keys2)
plt.figure(figsize=(20,10))
plt.title('Год издания PS2', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), year_count_values2, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), year_count_keys2, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
year_count3 = pd.value_counts(platorm3['Year'].values, sort=True)
year_count_keys3, year_count_values3 = dict_sort(dict(year_count3)) 
del year_count_values3[11]
del year_count_keys3[11]

for i in range(year_count3.values.size-1):
  j=i+1
  for j in range(year_count3.values.size-1):
    if(year_count_keys3[j]>year_count_keys3[i]):
      h = year_count_values3[j]
      year_count_values3[j] = year_count_values3[i]
      year_count_values3[i] = h

      n = year_count_keys3[j]
      year_count_keys3[j] = year_count_keys3[i]
      year_count_keys3[i] = n


TOP_breed = len(year_count_keys3)
plt.figure(figsize=(20,10))
plt.title('Год издания PS3', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), year_count_values3, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), year_count_keys3, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
year_count4 = pd.value_counts(platorm4['Year'].values, sort=True)
year_count_keys4, year_count_values4 = dict_sort(dict(year_count4)) 
del year_count_values4[6]
del year_count_keys4[6]

for i in range(year_count4.values.size-1):
  j=i+1
  for j in range(year_count4.values.size-1):
    if(year_count_keys4[j]>year_count_keys4[i]):
      h = year_count_values4[j]
      year_count_values4[j] = year_count_values4[i]
      year_count_values4[i] = h

      n = year_count_keys4[j]
      year_count_keys4[j] = year_count_keys4[i]
      year_count_keys4[i] = n

TOP_breed = len(year_count_keys4)
plt.figure(figsize=(20,10))
plt.title('Год издания Wii', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), year_count_values4, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), year_count_keys4, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
year_count5 = pd.value_counts(platorm5['Year'].values, sort=True)
year_count_keys5, year_count_values5 = dict_sort(dict(year_count5)) 
del year_count_values5[10]
del year_count_keys5[10]

for i in range(year_count5.values.size-1):
  j=i+1
  for j in range(year_count5.values.size-1):
    if(year_count_keys5[j]>year_count_keys5[i]):
      h = year_count_values5[j]
      year_count_values5[j] = year_count_values5[i]
      year_count_values5[i] = h

      n = year_count_keys5[j]
      year_count_keys5[j] = year_count_keys5[i]
      year_count_keys5[i] = n

TOP_breed = len(year_count_keys5)
plt.figure(figsize=(20,10))
plt.title('Год издания X360', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), year_count_values5, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), year_count_keys5, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
year_count6 = pd.value_counts(platorm6['Year'].values, sort=True)
year_count_keys6, year_count_values6 = dict_sort(dict(year_count6)) 
del year_count_values6[9]
del year_count_keys6[9]

for i in range(year_count6.values.size-1):
  j=i+1
  for j in range(year_count6.values.size-1):
    if(year_count_keys6[j]>year_count_keys6[i]):
      h = year_count_values6[j]
      year_count_values6[j] = year_count_values6[i]
      year_count_values6[i] = h

      n = year_count_keys6[j]
      year_count_keys6[j] = year_count_keys6[i]
      year_count_keys6[i] = n

TOP_breed = len(year_count_keys6)
plt.figure(figsize=(20,10))
plt.title('Год издания PSP', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), year_count_values6, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), year_count_keys6, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()

# %%
year_count7 = pd.value_counts(platorm7['Year'].values, sort=True)
year_count_keys7, year_count_values7 = dict_sort(dict(year_count7)) 
del year_count_values7[9]
del year_count_keys7[9]

for i in range(year_count7.values.size-1):
  j=i+1
  for j in range(year_count7.values.size-1):
    if(year_count_keys7[j]>year_count_keys7[i]):
      h = year_count_values7[j]
      year_count_values7[j] = year_count_values7[i]
      year_count_values7[i] = h

      n = year_count_keys7[j]
      year_count_keys7[j] = year_count_keys7[i]
      year_count_keys7[i] = n

TOP_breed = len(year_count_keys7)
plt.figure(figsize=(20,10))
plt.title('Год издания PS', fontsize=PLOT_LABEL_FONT_SIZE)
plt.bar(np.arange(TOP_breed), year_count_values7, color=getColors(TOP_breed)) #метод построения гистаграмм
plt.xticks(np.arange(TOP_breed), year_count_keys7, rotation=90, fontsize=PLOT_LABEL_FONT_SIZE)
plt.yticks(fontsize=PLOT_LABEL_FONT_SIZE) 
plt.ylabel('Количество игр изданных в год', fontsize=PLOT_LABEL_FONT_SIZE) 
plt.show()
